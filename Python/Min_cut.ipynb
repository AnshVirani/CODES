# %%
import random
import copy

# %% [markdown]
# single run of karger's Algorithm

# %%
def karger_min_cut(graph):
    while len(graph) > 2:
        # choose a random edge
        v1 = random.choice(list(graph.keys()))
        v2 = random.choice(graph[v1])
        
        print(f"Graph: {graph}")
        print(f"Contracting Edge: ({v1}, {v2})")
        
        # create new node for the contracted edge
        new_node = f"{v1}_{v2}"
        
        # add new node to the graph
        graph[new_node] = [neighbor for neighbor in graph[v1] + graph[v2] if neighbor != v1 and neighbor != v2]
        
        # connect the new node to the neighbors
        for neighbor in graph[new_node]:
            graph[neighbor] = [new_node if x == v1 or x == v2 else x for x in graph[neighbor]]
            
        # remove the chosen edges and contract nodes
        del graph[v1]
        del graph[v2]
        
        print(f"Graph: {graph}")
        print('-'*60)
        
    return len(graph[list(graph.keys())[0]])

# Example usage:
graph = {
    1: [2, 3, 4],
    2: [1, 3],
    3: [1, 2, 4],
    4: [1, 3]
}

# run karger's algorithm
karger_result = karger_min_cut(copy.deepcopy(graph))

print(f"Karger's Min Cut: {karger_result}")
# Out:
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (2_3, 1)
# Graph: {4: ['2_3_1', '2_3_1'], '2_3_1': [4, 4]}
# ------------------------------------------------------------
# Karger's Min Cut: 2

# %% [markdown]
# Multiple time run of karger's algorithm

# %%
num_trials = 10**2
min_cut = float('inf')

for _ in range(num_trials):
    current_cut = karger_min_cut(copy.deepcopy(graph))
    min_cut = min(min_cut, current_cut)
print(f"Kargwer's Min Cut: {min_cut}")
# Out:
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (1, 4)
# Graph: {'2_3': ['1_4', '1_4', '1_4'], '1_4': ['2_3', '2_3', '2_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (2, 4_3)
# Graph: {1: ['2_4_3', '2_4_3', '2_4_3'], '2_4_3': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (3, 4)
# Graph: {'2_1': ['3_4', '3_4', '3_4'], '3_4': ['2_1', '2_1', '2_1']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (3, 1_4)
# Graph: {2: ['3_1_4', '3_1_4'], '3_1_4': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 4)
# Graph: {1: [2, '3_4', '3_4'], 2: [1, '3_4'], '3_4': [1, 2, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, '3_4', '3_4'], 2: [1, '3_4'], '3_4': [1, 2, 1]}
# Contracting Edge: (2, 3_4)
# Graph: {1: ['2_3_4', '2_3_4', '2_3_4'], '2_3_4': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (3, 4)
# Graph: {'2_1': ['3_4', '3_4', '3_4'], '3_4': ['2_1', '2_1', '2_1']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (2_1, 3)
# Graph: {4: ['2_1_3', '2_1_3'], '2_1_3': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (4, 2_3)
# Graph: {1: ['4_2_3', '4_2_3', '4_2_3'], '4_2_3': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (2_1, 3)
# Graph: {4: ['2_1_3', '2_1_3'], '2_1_3': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (4, 2_3)
# Graph: {1: ['4_2_3', '4_2_3', '4_2_3'], '4_2_3': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (3_1, 4)
# Graph: {2: ['3_1_4', '3_1_4'], '3_1_4': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 2)
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# ------------------------------------------------------------
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# Contracting Edge: (4, 1)
# Graph: {'3_2': ['4_1', '4_1', '4_1'], '4_1': ['3_2', '3_2', '3_2']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (4_3, 2)
# Graph: {1: ['4_3_2', '4_3_2', '4_3_2'], '4_3_2': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (1, 4)
# Graph: {'2_3': ['1_4', '1_4', '1_4'], '1_4': ['2_3', '2_3', '2_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (2, 3)
# Graph: {'1_4': ['2_3', '2_3', '2_3'], '2_3': ['1_4', '1_4', '1_4']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 2)
# Graph: {3: ['1_2', '1_2', 4], 4: ['1_2', 3], '1_2': [3, 4, 3]}
# ------------------------------------------------------------
# Graph: {3: ['1_2', '1_2', 4], 4: ['1_2', 3], '1_2': [3, 4, 3]}
# Contracting Edge: (4, 1_2)
# Graph: {3: ['4_1_2', '4_1_2', '4_1_2'], '4_1_2': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (3, 4_1)
# Graph: {2: ['3_4_1', '3_4_1'], '3_4_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 2)
# Graph: {3: ['1_2', '1_2', 4], 4: ['1_2', 3], '1_2': [3, 4, 3]}
# ------------------------------------------------------------
# Graph: {3: ['1_2', '1_2', 4], 4: ['1_2', 3], '1_2': [3, 4, 3]}
# Contracting Edge: (1_2, 3)
# Graph: {4: ['1_2_3', '1_2_3'], '1_2_3': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (4, 2_3)
# Graph: {1: ['4_2_3', '4_2_3', '4_2_3'], '4_2_3': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (2_3, 4)
# Graph: {1: ['2_3_4', '2_3_4', '2_3_4'], '2_3_4': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (2, 4_1)
# Graph: {3: ['2_4_1', '2_4_1', '2_4_1'], '2_4_1': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 3)
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# Contracting Edge: (1_3, 2)
# Graph: {4: ['1_3_2', '1_3_2'], '1_3_2': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (2_3, 4)
# Graph: {1: ['2_3_4', '2_3_4', '2_3_4'], '2_3_4': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (2, 1)
# Graph: {'4_3': ['2_1', '2_1', '2_1'], '2_1': ['4_3', '4_3', '4_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 3)
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# Contracting Edge: (4, 1_3)
# Graph: {2: ['4_1_3', '4_1_3'], '4_1_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (4, 1)
# Graph: {'2_3': ['4_1', '4_1', '4_1'], '4_1': ['2_3', '2_3', '2_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (4, 1)
# Graph: {'2_3': ['4_1', '4_1', '4_1'], '4_1': ['2_3', '2_3', '2_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (1, 2_3)
# Graph: {4: ['1_2_3', '1_2_3'], '1_2_3': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 3)
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# Contracting Edge: (2, 1_3)
# Graph: {4: ['2_1_3', '2_1_3'], '2_1_3': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (4, 2_1)
# Graph: {3: ['4_2_1', '4_2_1', '4_2_1'], '4_2_1': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (1, 2_3)
# Graph: {4: ['1_2_3', '1_2_3'], '1_2_3': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (3, 4_1)
# Graph: {2: ['3_4_1', '3_4_1'], '3_4_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 3)
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# Contracting Edge: (2, 1_3)
# Graph: {4: ['2_1_3', '2_1_3'], '2_1_3': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (4_1, 3)
# Graph: {2: ['4_1_3', '4_1_3'], '4_1_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (2_1, 4)
# Graph: {3: ['2_1_4', '2_1_4', '2_1_4'], '2_1_4': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (1_4, 3)
# Graph: {2: ['1_4_3', '1_4_3'], '1_4_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (1, 2)
# Graph: {'4_3': ['1_2', '1_2', '1_2'], '1_2': ['4_3', '4_3', '4_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (2, 1_4)
# Graph: {3: ['2_1_4', '2_1_4', '2_1_4'], '2_1_4': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (3_1, 4)
# Graph: {2: ['3_1_4', '3_1_4'], '3_1_4': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (1, 4)
# Graph: {'2_3': ['1_4', '1_4', '1_4'], '1_4': ['2_3', '2_3', '2_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (3_1, 4)
# Graph: {2: ['3_1_4', '3_1_4'], '3_1_4': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 3)
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# Contracting Edge: (4, 1_3)
# Graph: {2: ['4_1_3', '4_1_3'], '4_1_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 3)
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# Contracting Edge: (2, 1_3)
# Graph: {4: ['2_1_3', '2_1_3'], '2_1_3': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (4, 3_1)
# Graph: {2: ['4_3_1', '4_3_1'], '4_3_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (2_1, 4)
# Graph: {3: ['2_1_4', '2_1_4', '2_1_4'], '2_1_4': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (2, 1)
# Graph: {'4_3': ['2_1', '2_1', '2_1'], '2_1': ['4_3', '4_3', '4_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (2_1, 3)
# Graph: {4: ['2_1_3', '2_1_3'], '2_1_3': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (3, 2_1)
# Graph: {4: ['3_2_1', '3_2_1'], '3_2_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (1, 2)
# Graph: {'4_3': ['1_2', '1_2', '1_2'], '1_2': ['4_3', '4_3', '4_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (3_1, 4)
# Graph: {2: ['3_1_4', '3_1_4'], '3_1_4': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 3)
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['1_3', '1_3'], 4: ['1_3', '1_3'], '1_3': [2, 4, 2, 4]}
# Contracting Edge: (4, 1_3)
# Graph: {2: ['4_1_3', '4_1_3'], '4_1_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (2, 1)
# Graph: {'4_3': ['2_1', '2_1', '2_1'], '2_1': ['4_3', '4_3', '4_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (3, 4_1)
# Graph: {2: ['3_4_1', '3_4_1'], '3_4_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (2_3, 1)
# Graph: {4: ['2_3_1', '2_3_1'], '2_3_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (1_4, 3)
# Graph: {2: ['1_4_3', '1_4_3'], '1_4_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 2)
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# ------------------------------------------------------------
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# Contracting Edge: (4, 3_2)
# Graph: {1: ['4_3_2', '4_3_2', '4_3_2'], '4_3_2': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (3, 2_1)
# Graph: {4: ['3_2_1', '3_2_1'], '3_2_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 2)
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# ------------------------------------------------------------
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# Contracting Edge: (3_2, 4)
# Graph: {1: ['3_2_4', '3_2_4', '3_2_4'], '3_2_4': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (3_1, 4)
# Graph: {2: ['3_1_4', '3_1_4'], '3_1_4': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (1_4, 3)
# Graph: {2: ['1_4_3', '1_4_3'], '1_4_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (2, 1_4)
# Graph: {3: ['2_1_4', '2_1_4', '2_1_4'], '2_1_4': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (3, 2)
# Graph: {'4_1': ['3_2', '3_2', '3_2'], '3_2': ['4_1', '4_1', '4_1']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (3_1, 2)
# Graph: {4: ['3_1_2', '3_1_2'], '3_1_2': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (2, 3_1)
# Graph: {4: ['2_3_1', '2_3_1'], '2_3_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 2)
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# ------------------------------------------------------------
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# Contracting Edge: (1, 3_2)
# Graph: {4: ['1_3_2', '1_3_2'], '1_3_2': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (3, 4)
# Graph: {'2_1': ['3_4', '3_4', '3_4'], '3_4': ['2_1', '2_1', '2_1']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (4, 2_1)
# Graph: {3: ['4_2_1', '4_2_1', '4_2_1'], '4_2_1': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (3, 1_4)
# Graph: {2: ['3_1_4', '3_1_4'], '3_1_4': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (2_3, 1)
# Graph: {4: ['2_3_1', '2_3_1'], '2_3_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (3, 4_1)
# Graph: {2: ['3_4_1', '3_4_1'], '3_4_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (2_3, 1)
# Graph: {4: ['2_3_1', '2_3_1'], '2_3_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 4)
# Graph: {1: [2, '3_4', '3_4'], 2: [1, '3_4'], '3_4': [1, 2, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, '3_4', '3_4'], 2: [1, '3_4'], '3_4': [1, 2, 1]}
# Contracting Edge: (2, 1)
# Graph: {'3_4': ['2_1', '2_1', '2_1'], '2_1': ['3_4', '3_4', '3_4']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 2)
# Graph: {3: ['1_2', '1_2', 4], 4: ['1_2', 3], '1_2': [3, 4, 3]}
# ------------------------------------------------------------
# Graph: {3: ['1_2', '1_2', 4], 4: ['1_2', 3], '1_2': [3, 4, 3]}
# Contracting Edge: (3, 4)
# Graph: {'1_2': ['3_4', '3_4', '3_4'], '3_4': ['1_2', '1_2', '1_2']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (4, 3_1)
# Graph: {2: ['4_3_1', '4_3_1'], '4_3_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (4_3, 1)
# Graph: {2: ['4_3_1', '4_3_1'], '4_3_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 4)
# Graph: {1: [2, '3_4', '3_4'], 2: [1, '3_4'], '3_4': [1, 2, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, '3_4', '3_4'], 2: [1, '3_4'], '3_4': [1, 2, 1]}
# Contracting Edge: (1, 2)
# Graph: {'3_4': ['1_2', '1_2', '1_2'], '1_2': ['3_4', '3_4', '3_4']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 4)
# Graph: {1: [2, '3_4', '3_4'], 2: [1, '3_4'], '3_4': [1, 2, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, '3_4', '3_4'], 2: [1, '3_4'], '3_4': [1, 2, 1]}
# Contracting Edge: (2, 1)
# Graph: {'3_4': ['2_1', '2_1', '2_1'], '2_1': ['3_4', '3_4', '3_4']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (4, 3_1)
# Graph: {2: ['4_3_1', '4_3_1'], '4_3_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (3, 4_1)
# Graph: {2: ['3_4_1', '3_4_1'], '3_4_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (4_3, 1)
# Graph: {2: ['4_3_1', '4_3_1'], '4_3_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (1, 4)
# Graph: {'2_3': ['1_4', '1_4', '1_4'], '1_4': ['2_3', '2_3', '2_3']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (4_1, 3)
# Graph: {2: ['4_1_3', '4_1_3'], '4_1_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (4_3, 2)
# Graph: {1: ['4_3_2', '4_3_2', '4_3_2'], '4_3_2': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (2, 3_1)
# Graph: {4: ['2_3_1', '2_3_1'], '2_3_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 2)
# Graph: {3: ['1_2', '1_2', 4], 4: ['1_2', 3], '1_2': [3, 4, 3]}
# ------------------------------------------------------------
# Graph: {3: ['1_2', '1_2', 4], 4: ['1_2', 3], '1_2': [3, 4, 3]}
# Contracting Edge: (4, 1_2)
# Graph: {3: ['4_1_2', '4_1_2', '4_1_2'], '4_1_2': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (4_3, 2)
# Graph: {1: ['4_3_2', '4_3_2', '4_3_2'], '4_3_2': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (4_3, 1)
# Graph: {2: ['4_3_1', '4_3_1'], '4_3_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (1_4, 3)
# Graph: {2: ['1_4_3', '1_4_3'], '1_4_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 1)
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# ------------------------------------------------------------
# Graph: {3: ['2_1', '2_1', 4], 4: ['2_1', 3], '2_1': [3, 3, 4]}
# Contracting Edge: (3, 2_1)
# Graph: {4: ['3_2_1', '3_2_1'], '3_2_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (4, 3_1)
# Graph: {2: ['4_3_1', '4_3_1'], '4_3_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (2, 3)
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# ------------------------------------------------------------
# Graph: {1: ['2_3', '2_3', 4], 4: [1, '2_3'], '2_3': [1, 1, 4]}
# Contracting Edge: (2_3, 1)
# Graph: {4: ['2_3_1', '2_3_1'], '2_3_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 2)
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# ------------------------------------------------------------
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# Contracting Edge: (3_2, 1)
# Graph: {4: ['3_2_1', '3_2_1'], '3_2_1': [4, 4]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (3, 2)
# Graph: {'1_4': ['3_2', '3_2', '3_2'], '3_2': ['1_4', '1_4', '1_4']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (2, 4_1)
# Graph: {3: ['2_4_1', '2_4_1', '2_4_1'], '2_4_1': [3, 3, 3]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (1, 4)
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# ------------------------------------------------------------
# Graph: {2: ['1_4', 3], 3: ['1_4', 2, '1_4'], '1_4': [2, 3, 3]}
# Contracting Edge: (3, 2)
# Graph: {'1_4': ['3_2', '3_2', '3_2'], '3_2': ['1_4', '1_4', '1_4']}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (4_3, 1)
# Graph: {2: ['4_3_1', '4_3_1'], '4_3_1': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 1)
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# ------------------------------------------------------------
# Graph: {2: ['4_1', 3], 3: ['4_1', 2, '4_1'], '4_1': [3, 2, 3]}
# Contracting Edge: (4_1, 3)
# Graph: {2: ['4_1_3', '4_1_3'], '4_1_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 2)
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# ------------------------------------------------------------
# Graph: {1: ['3_2', '3_2', 4], 4: [1, '3_2'], '3_2': [1, 4, 1]}
# Contracting Edge: (4, 3_2)
# Graph: {1: ['4_3_2', '4_3_2', '4_3_2'], '4_3_2': [1, 1, 1]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (4, 3)
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, '4_3', '4_3'], 2: [1, '4_3'], '4_3': [1, 1, 2]}
# Contracting Edge: (1, 4_3)
# Graph: {2: ['1_4_3', '1_4_3'], '1_4_3': [2, 2]}
# ------------------------------------------------------------
# Graph: {1: [2, 3, 4], 2: [1, 3], 3: [1, 2, 4], 4: [1, 3]}
# Contracting Edge: (3, 1)
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# ------------------------------------------------------------
# Graph: {2: ['3_1', '3_1'], 4: ['3_1', '3_1'], '3_1': [2, 4, 2, 4]}
# Contracting Edge: (4, 3_1)
# Graph: {2: ['4_3_1', '4_3_1'], '4_3_1': [2, 2]}
# ------------------------------------------------------------
# Kargwer's Min Cut: 2
